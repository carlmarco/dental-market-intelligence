# %%
import pandas as pd
import numpy as np

# %%
nppes = pd.read_parquet('../data/processed/nppes_dental_providers.parquet')
cbp = pd.read_parquet('../data/processed/cbp_dental_2018_2023.parquet')
gcspi = pd.read_parquet('../data/processed/gscpi.parquet')
acs = pd.read_parquet('../data/processed/acs_demographics_2021.parquet')

# %%
cbp
# Out:
#       ESTAB  EMP PAYANN                                             NAME  \
# 0         5   27   1072                   Prince Edward County, Virginia
# 1        19  201  10488                      Rockingham County, Virginia
# 2         3   21   1257                           Scott County, Virginia
# 3        40  324  17720                    Spotsylvania County, Virginia
# 4         3   13    683                          Clarke County, Virginia
# ...     ...  ...    ...                                              ...
# 13129     4   12    150                  Villalba Municipio, Puerto Rico
# 13130     5   23    473                   Yabucoa Municipio, Puerto Rico
# 13131    10   35    815                     Yauco Municipio, Puerto Rico
# 13132    12   55   2862   St. Croix Island, United States Virgin Islands
# 13133    12  104   6127  St. Thomas Island, United States Virgin Islands
#
#       NAICS2017 state county
# 0        621210    51    147
# 1        621210    51    165
# 2        621210    51    169
# 3        621210    51    177
# 4        621210    51    043
# ...         ...   ...    ...
# 13129    621210    72    149
# 13130    621210    72    151
# 13131    621210    72    153
# 13132    621210    78    010
# 13133    621210    78    030
#
# [13134 rows x 7 columns]

# %%
len(acs['county'].values.unique())
# Out:
# 326

# %%
acs
# Out:
#       B19013_001E  B01002_001E  B27001_001E  B27001_004E  B27001_007E  \
# 0         62660.0         38.5      56955.0       2191.0       4853.0
# 1         64346.0         43.4     224339.0       7057.0      17568.0
# 2         36422.0         40.2      22295.0        749.0       1959.0
# 3         54277.0         39.7      21000.0        726.0       1753.0
# 4         52830.0         41.1      58437.0       1956.0       5083.0
# ...           ...          ...          ...          ...          ...
# 3216      21507.0         43.1      54340.0       1156.0       3946.0
# 3217      14942.0         43.6       8317.0        333.0        502.0
# 3218      20722.0         42.0      22237.0        645.0       1795.0
# 3219      17267.0         44.9      31042.0        634.0       2330.0
# 3220      16444.0         45.5      34557.0        781.0       2605.0
#
#       B27001_010E  B27001_013E  B27001_016E  B27001_019E  B27001_022E  ...  \
# 0          2012.0       2372.0       2665.0       3665.0       3329.0  ...
# 1          7060.0       7338.0      10647.0      12194.0      14169.0  ...
# 2           625.0        920.0        771.0       1153.0       1180.0  ...
# 3           786.0       1223.0       1205.0       1167.0       1323.0  ...
# 4          2187.0       2184.0       2817.0       3541.0       3684.0  ...
# ...           ...          ...          ...          ...          ...  ...
# 3216       1856.0       2511.0       2658.0       2937.0       3004.0  ...
# 3217        302.0        163.0        362.0        321.0        573.0  ...
# 3218        984.0       1137.0       1059.0       1211.0       1456.0  ...
# 3219       1322.0       1240.0       1458.0       1806.0       1989.0  ...
# 3220       1499.0       1490.0       1522.0       2041.0       1998.0  ...
#
#       B27001_041E  B27001_044E  B27001_047E  B27001_050E  B27001_053E  \
# 0          2962.0       3488.0       3819.0       3414.0       2782.0
# 1          9015.0      12480.0      13222.0      16093.0      14902.0
# 2           944.0       1078.0       1186.0       1422.0       1572.0
# 3           908.0       1083.0       1245.0       1242.0       1076.0
# 4          2563.0       2946.0       3053.0       3672.0       3246.0
# ...           ...          ...          ...          ...          ...
# 3216       2812.0       3209.0       3357.0       3631.0       3274.0
# 3217         40.0        457.0        463.0        549.0        521.0
# 3218       1261.0       1257.0       1440.0       1720.0       1350.0
# 3219       1568.0       1785.0       2018.0       2187.0       2029.0
# 3220       1697.0       2103.0       2215.0       2529.0       2376.0
#
#       B27001_056E  state  county  insured_total  pct_insured
# 0          1995.0     01     001        52459.0    92.106049
# 1          9647.0     01     003       202513.0    90.270974
# 2          1075.0     01     005        19982.0    89.625477
# 3           811.0     01     007        18905.0    90.023810
# 4          2429.0     01     009        52583.0    89.982374
# ...           ...    ...     ...            ...          ...
# 3216       2999.0     72     145        49128.0    90.408539
# 3217        470.0     72     147         7181.0    86.341229
# 3218        931.0     72     149        21530.0    96.820614
# 3219       1614.0     72     151        29295.0    94.372141
# 3220       1997.0     72     153        32521.0    94.108285
#
# [3221 rows x 25 columns]

# %%
acs.groupby('state')['county'].nunique().sum()
# Out:
# np.int64(3221)

# %%
nppes['county'] = nppes["practice_location_postal"].map(crosswalk['COUNTY'])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 nppes['county'] = nppes["practice_location_postal"].map(crosswalk.set_index('ZIP')['COUNTY'])
#
# File c:\dental-market\dental-market-intelligence\venv\Lib\site-packages\pandas\core\series.py:4675, in Series.map(self, func, na_action, engine, **kwargs)
#    4673 if callable(func):
#    4674     func = functools.partial(func, **kwargs)
# -> 4675 new_values = self._map_values(func, na_action=na_action)
#    4676 return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4677     self, method="map"
#    4678 )
#
# File c:\dental-market\dental-market-intelligence\venv\Lib\site-packages\pandas\core\base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File c:\dental-market\dental-market-intelligence\venv\Lib\site-packages\pandas\core\arrays\arrow\array.py:1741, in ArrowExtensionArray.map(self, mapper, na_action)
#    1735     return map_array(self.to_numpy(), mapper, na_action=na_action)
#    1736 else:
#    1737     # For "mM" cases, the super() method passes `self` without the
#    1738     #  to_numpy call, which inside map_array casts to ndarray[object].
#    1739     #  Without the to_numpy() call, NA is preserved instead of changed
#    1740     #  to None.
# -> 1741     return super().map(mapper, na_action)
#
# File c:\dental-market\dental-market-intelligence\venv\Lib\site-packages\pandas\core\arrays\base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File c:\dental-market\dental-market-intelligence\venv\Lib\site-packages\pandas\core\algorithms.py:1699, in map_array(arr, mapper, na_action)
#    1695     mapper = mapper[mapper.index.notna()]
#    1697 # Since values were input this means we came from either
#    1698 # a dict or a series and mapper should be an index
# -> 1699 indexer = mapper.index.get_indexer(arr)
#    1700 new_values = take_nd(mapper._values, indexer)
#    1702 return new_values
#
# File c:\dental-market\dental-market-intelligence\venv\Lib\site-packages\pandas\core\indexes\base.py:3728, in Index.get_indexer(self, target, method, limit, tolerance)
#    3725 self._check_indexing_method(method, limit, tolerance)
#    3727 if not self._index_as_unique:
# -> 3728     raise InvalidIndexError(self._requires_unique_msg)
#    3730 if len(target) == 0:
#    3731     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
crosswalk = pd.read_excel('..\ZIP_COUNTY_122025.xlsx', sheet_name='Export Worksheet', dtype={'ZIP': str, 'COUNTY': str})
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\CMarco\AppData\Local\Temp\ipykernel_25256\392708273.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   crosswalk = pd.read_excel('..\ZIP_COUNTY_122025.xlsx', sheet_name='Export Worksheet', dtype={'ZIP': str, 'COUNTY': str})

# %%
crosswalk
# Out:
#          ZIP COUNTY USPS_ZIP_PREF_CITY USPS_ZIP_PREF_STATE  RES_RATIO  \
# 0      00501  36103         HOLTSVILLE                  NY   0.000000
# 1      00601  72081           ADJUNTAS                  PR   0.002549
# 2      00601  72001           ADJUNTAS                  PR   0.997451
# 3      00602  72117             AGUADA                  PR   0.000584
# 4      00602  72005             AGUADA                  PR   0.000000
# ...      ...    ...                ...                 ...        ...
# 54566  99926  02198         METLAKATLA                  AK   1.000000
# 54567  99927  02198        POINT BAKER                  AK   0.000000
# 54568  99928  02130          WARD COVE                  AK   0.000000
# 54569  99929  02275           WRANGELL                  AK   1.000000
# 54570  99950  02198          KETCHIKAN                  AK   1.000000
#
#        BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0       1.000000   0.000000   1.000000
# 1       0.005051   0.012048   0.002947
# 2       0.994949   0.987952   0.997053
# 3       0.000000   0.000000   0.000530
# 4       0.001016   0.000000   0.000076
# ...          ...        ...        ...
# 54566   0.000000   1.000000   1.000000
# 54567   0.000000   1.000000   1.000000
# 54568   0.000000   1.000000   1.000000
# 54569   1.000000   1.000000   1.000000
# 54570   0.000000   0.000000   1.000000
#
# [54571 rows x 8 columns]
